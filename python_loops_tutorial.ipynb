# %% [markdown]
# 📚 Mastering Loops in Python: for, while, and IterablesM

# %% [markdown]
# 📝 Introduction
#
# Loops are essential to repeat actions in your code without duplication.
# In this tutorial, you will learn how to:
#
# * Use for and while loops
#
# * Control loop execution with break and continue
#
# * Use enumerate() and zip() to iterate iterables efficiently
#
# * Iterate over dictionaries
#
# * Avoid common mistakes like indentation errors or infinite loops

# %% [markdown]
# 1️⃣ Step 1: For Loops

# %% [markdown]
# 🛠 Basic For Loop

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Explanation:
#
# * Loops through each element in the list fruits.
#
# * The indented block runs for each element.
#
# 💡 Tip: Always check your indentation to avoid IndentationError.
#
# ⚠️ Common Mistake: Forgetting the colon : after for causes a syntax error.

# %% [markdown]
# 2️⃣ Step 2: While Loops

# %% [markdown]
# 🛠 Basic While Loop

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Explanation:
#
# * while repeats the block as long as the condition is True.
#
# * Here, count increments until it reaches 5.
#
# 💡 Tip: Ensure the condition will eventually become False to avoid infinite loops.
#
# ⚠️ Common Mistake: Forgetting to increment count → infinite loop.

# %% [markdown]
# 3️⃣ Step 3: Break and Continue

# %% [markdown]
# 🛠 Break Example

# %%
for i in range(10):
    if i == 5:
        break  # stop the loop
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 🛠 Continue Example

# %%
for i in range(5):
    if i == 2:
        continue  # skip this iteration
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %% [markdown]
# 💡 Tip: break stops the loop, continue skips just the current iteration.

# %% [markdown]
# 4️⃣ Step 4: Enumerate() and Zip()

# %% [markdown]
# 🛠 Using enumerate()

# %%
fruits = ["apple", "banana", "cherry"]

for index, fruit in enumerate(fruits, start=1):
    print(index, fruit)
# Out:
# 1 apple
# 2 banana
# 3 cherry

# %% [markdown]
# 🛠 Using zip()

# %%
names = ["Alice", "Bob", "Charlie"]
ages = [25, 30, 22]

for name, age in zip(names, ages):
    print(f"{name} is {age} years old")
# Out:
# Alice is 25 years old
# Bob is 30 years old
# Charlie is 22 years old

# %% [markdown]
# 💡 Tip: enumerate() adds an index, zip() combines multiple iterables.

# %% [markdown]
# 5️⃣ Step 5: Iterating Over Dictionaries

# %%
person = {"name": "Alice", "age": 25, "city": "Paris"}

for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# name: Alice
# age: 25
# city: Paris

# %% [markdown]
# 💡 Tip: Use .items() to iterate both keys and values at the same time.

# %% [markdown]
# 🏁 Conclusion
#
# In this tutorial, you learned how to:
#
# * Use for and while loops
#
# * Control loops with break and continue
#
# * Use enumerate() and zip() for efficient iteration
#
# * Iterate over dictionaries
