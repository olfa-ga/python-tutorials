# %% [markdown]
# 📚 Mastering Python Functions, Scope, and Arguments

# %% [markdown]
# 📝 Introduction
#
# Functions are core building blocks in Python. They allow you to organize your code into reusable chunks, improve readability, and avoid repetition.
#
# In this tutorial, you will learn:
#
# * How to define and call functions
#
# * The difference between local and global scope
#
# * How to use arguments, default values, *args, and **kwargs
#
# * Best practices and common mistakes

# %% [markdown]
# 1️⃣ Step 1: Defining and Calling Functions

# %%
🛠 Creating a Function

# %%
def greet(name):
    """Print a greeting message for the given name."""
    print(f"Hello, {name}!")

# %%
#Call the function:

greet("Alice")
# Out:
# Hello, Alice!

# %% [markdown]
# Explanation:
#
# * def keyword defines a function.
#
# * name is a parameter.
#
# * The function prints a greeting when called.
#
# 💡 Tip: Always include a docstring to explain what your function does.
#
# ⚠️ Common Mistake: Forgetting parentheses () when calling a function will return the function object instead of executing it.

# %% [markdown]
# 2️⃣ Step 2: Return Values

# %% [markdown]
# 🛠 Functions That Return Values

# %%
def add(a, b):
    """Return the sum of two numbers."""
    return a + b

result = add(5, 3)
print(result)
# Out:
# 8

# %% [markdown]
# Why it matters:
#
# * return gives output back to the caller.
#
# * Without return, the function returns None by default.
#
# 💡 Tip: Use return to pass computed results instead of printing inside the function.

# %% [markdown]
# 3️⃣ Step 3: Function Arguments

# %% [markdown]
# Positional Arguments

# %%
def multiply(x, y):
    return x * y

print(multiply(2, 3))  # x=2, y=3
# Out:
# 6

# %% [markdown]
# Keyword Arguments

# %%
print(multiply(y=4, x=5))  # order doesn't matter
# Out:
# 20

# %% [markdown]
# Default Arguments

# %%
def greet(name="Guest"):
    print(f"Hello, {name}!")

greet()       # Uses default
greet("Bob")  # Overrides default
# Out:
# Hello, Guest!
# Hello, Bob!

# %% [markdown]
# 💡 Tip: Default arguments make your functions flexible and prevent errors if a value is missing.
# ⚠️ Common Mistake: Never put a non-default argument after a default argument; Python will raise a SyntaxError.

# %% [markdown]
# 4️⃣ Step 4: Variable-Length Arguments

# %% [markdown]
# Using *args for Multiple Positional Arguments

# %%
def sum_all(*args):
    return sum(args)

print(sum_all(1, 2, 3, 4))
# Out:
# 10

# %% [markdown]
# Using **kwargs for Keyword Arguments

# %%
def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

print_info(name="Alice", age=22, major="CS")
# Out:
# name: Alice
# age: 22
# major: CS

# %% [markdown]
# Explanation:
#
# *args lets you pass any number of positional arguments.
#
# **kwargs lets you pass any number of keyword arguments.
#
# 💡 Tip: Combine *args and **kwargs in a function to handle both types of flexible arguments.

# %% [markdown]
# 5️⃣ Step 5: Scope in Python

# %% [markdown]
# Local vs Global Variables

# %%
x = 10  # global variable

def print_local():
    x = 5  # local variable
    print("Inside function:", x)

print_local()
print("Outside function:", x)
# Out:
# Inside function: 5
# Outside function: 10

# %% [markdown]
# Explanation:
#
# * Variables defined inside a function are local.
#
# * Variables defined outside are global.

# %% [markdown]
# Using global Keyword

# %%
def change_global():
    global x
    x = 20

change_global()
print(x)
# Out:
# 20

# %% [markdown]
# 💡 Tip: Avoid modifying global variables when possible; it can make code harder to debug.
#
# ⚠️ Common Mistake: Assuming a local variable can automatically modify a global variable without global.

# %% [markdown]
# 6️⃣ Step 6: Lambda Functions

# %% [markdown]
# Anonymous Functions

# %%
square = lambda x: x**2
print(square(5))
# Out:
# 25

# %% [markdown]
# Explanation:
#
# * Lambda functions are one-line, anonymous functions.
#
# * Useful for short operations like sorting or mapping.

# %% [markdown]
# 🏁 Conclusion
#
# In this tutorial, you learned how to:
#
# * Define and call functions
#
# * Use return values instead of just printing
#
# * Handle positional, keyword, default, and flexible arguments
#
# * Understand variable scope (local vs global)
#
# * Use lambda functions for quick operations
