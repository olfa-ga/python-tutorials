# %% [markdown]
# 📚 Understanding Python Lists, Tuples, and Dictionaries

# %% [markdown]
# 📝 Introduction
#
# Python provides versatile data structures to store and manage data efficiently. In this tutorial, we’ll explore lists, tuples, and dictionaries, explain their differences, and show practical examples.
#
# By the end, you’ll understand how to manipulate each type effectively.

# %% [markdown]
# 1️⃣ Step 1: Working with Lists
# What is a List?
#
# A list is an ordered, mutable collection of items. Use it when you need a sequence of values that can change over time.

# %% [markdown]
# 🛠 Creating a List

# %%
fruits = ['apple', 'banana', 'cherry']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# Explanation:
#
# * fruits stores multiple string elements.
#
# * Lists are enclosed in square brackets [ ].
#
# 💡 Tip: Lists can store any type of object, including numbers, strings, or even other lists.

# %% [markdown]
# 🔧 Common List Operations

# %%
# Add an item
fruits.append('orange')

# Remove an item
fruits.remove('banana')

# Access by index
print(fruits[0])

# Slice a list
print(fruits[1:3])
# Out:
# apple
# ['cherry', 'orange']

# %% [markdown]
# Why it matters:
#
# * .append() adds new items dynamically.
#
# * .remove() deletes specific items.
#
# * MIndexing and slicing help extract parts of the list.
#
# ⚠️ Common Mistake: Using a wrong index raises an IndexError. Always check list length with len(fruits).

# %% [markdown]
# ✨ List Comprehensions

# %%
# Create a list of squares from 0 to 9
squares = [x**2 for x in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# Explanation:
#
# * A list comprehension is a concise way to create lists.
#
# * x**2 computes the square of each number in the range 0-9.
#
# 💡 Tip: Avoid complex expressions in list comprehensions; readability is key.

# %% [markdown]
# 2️⃣ Step 2: Working with Tuples
# 🔹 What is a Tuple?
#
# A tuple is an ordered, immutable collection. Use it for fixed sets of values, such as coordinates or RGB colors.

# %% [markdown]
# 🛠 Creating a Tuple

# %%
point = (10, 20)
print(point)
# Out:
# (10, 20)

# %% [markdown]
# Why it matters:
#
# * Tuples are immutable, so they cannot be changed after creation.
#
# * Use tuples to protect data integrity.

# %% [markdown]
# ✨ Tuple Unpacking

# %%
x, y = point
print(f"x={x}, y={y}")
# Out:
# x=10, y=20

# %% [markdown]
# Explanation:
#
# * Unpacking assigns tuple values to multiple variables in one line.
#
# ⚠️ Common Mistake: Trying to modify a tuple like point[0] = 5 will raise a TypeError.

# %% [markdown]
# 3️⃣ Step 3: Working with Dictionaries
# 🔑 What is a Dictionary?
#
# A dictionary stores data as key-value pairs. It’s perfect for structured data where each item has a unique identifier.

# %% [markdown]
# 🛠 Creating and Accessing a Dictionary

# %%
student = {'name': 'Alice', 'age': 22, 'major': 'CS'}
print(student)
print(student['name'])
# Out:
# {'name': 'Alice', 'age': 22, 'major': 'CS'}
# Alice

# %% [markdown]
# Why it matters:
#
# * Accessing values by keys is fast.
#
# * Dictionaries are ideal for JSON-like structures.

# %% [markdown]
# ✨ Modifying and Iterating

# %%
# Update and add entries
student['age'] = 23
student['gpa'] = 3.8

# Loop through dictionary
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# name: Alice
# age: 23
# major: CS
# gpa: 3.8

# %% [markdown]
# 💡 Tip: Use .items() to loop through both keys and values.
#
# ⚠️ Common Mistake: Accessing a non-existent key raises a KeyError. Use .get() to avoid errors.

# %% [markdown]
# 🏁 Conclusion
#
# In this tutorial, you learned to:
#
# * Create and manipulate lists, tuples, and dictionaries
#
# * Use list comprehensions for concise code
#
# * Unpack tuples and iterate dictionaries
#
# These fundamentals are core to Python programming and appear in data analysis, web development, and automation projects.
